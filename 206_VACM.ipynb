# %%
print("operador matematico")
print("ealiza la suma 4 + 4 =" , 4 + 4)
print("realiza la resta de 8 - 6 =" , 8 - 6)
# Out:
# operador matematico
# ealiza la suma 4 + 4 = 8
# realiza la resta de 8 - 6 = 2

# %%
print("realiza la multiplicacion de 5 * 4 =" , 5 * 4 )
print("realiza la multiplicacion de 8 * 9 =" , 8 * 9 )
print("realiza la multiplicacion de 3 * 7 =" , 3 * 7 )
print("realiza la multiplicacion de 6 * 4 =" , 6 * 4 )
print("realiza la multiplicacion de 4 * 9 =" , 4 * 9 )
print("realiza la multiplicacion de 12 * 5 =" , 12 * 5 )
print("realiza la muultiplicacion de 5 * 25 =" , 5 * 25 )
print("realiza la multiplicacion de 8 * 14 =" , 8 * 14 )
print("realiza la multiplicacion de 3 * 6 =" , 3 * 6 )
print("realiza la multiplicacion de 9 * 17 =" , 9 * 17 )
# Out:
# realiza la multiplicacion de 5 * 4 = 20
# realiza la multiplicacion de 8 * 9 = 72
# realiza la multiplicacion de 3 * 7 = 21
# realiza la multiplicacion de 6 * 4 = 24
# realiza la multiplicacion de 4 * 9 = 36
# realiza la multiplicacion de 12 * 5 = 60
# realiza la muultiplicacion de 5 * 25 = 125
# realiza la multiplicacion de 8 * 14 = 112
# realiza la multiplicacion de 3 * 6 = 18
# realiza la multiplicacion de 9 * 17 = 153

# %%
print("realiza la resta de  6 - 3 =" , 6 - 3 )
print("realiza la resta de  5 - 9 =" , 5 - 9 )
print("realiza la resta de 6 - 15 ="  , 6 - 15 )
print("realiza la resta de 8 - 2 =" , 8 - 2 )
print("realiza la resta de 2 - 4 =" , 2 - 4 )
print("realiza la resta de 8 - 11 =" , 8 - 11 )
print("realiza la resta de 4 - 31 =" , 4 - 31 )
print("realiza la resta de 6 - 47 =" , 6 - 47 )
print("realiza la resta de 7 - 55 =" , 7 * 55 )
print("realiza la resta de 3 - 1 =" , 3 - 1 )
# Out:
# realiza la resta de  6 - 3 = 3
# realiza la resta de  5 - 9 = -4
# realiza la resta de 6 - 15 = -9
# realiza la resta de 8 - 2 = 6
# realiza la resta de 2 - 4 = -2
# realiza la resta de 8 - 11 = -3
# realiza la resta de 4 - 31 = -27
# realiza la resta de 6 - 47 = -41
# realiza la resta de 7 - 55 = 385
# realiza la resta de 3 - 1 = 2

# %%
print("realiza la division de 6 / 8 =" , 6 / 8 )
print("realiza la division de  3 / 18 =" , 3 / 18 )
print("realiza la division de  4 / 20 =" , 4 / 20 )
print("realiza la division de 9 / 3 =" , 9 / 3 )
print("realiza la division de  7 / 21 =" , 7 / 21 )
print("realiza la division de 7 / 17 =" , 7 / 17 )
print("realiza la divison de 5 / 10 =" , 5 / 10 )
print("realiza la division de 3 / 6 =" ,3 / 6 )
print("realiza la division de  6 / 12 =" , 6 / 12 )
print("realiza la division de 9 / 2 =" , 9 / 2 )
# Out:
# realiza la division de 6 / 8 = 0.75
# realiza la division de  3 / 18 = 0.16666666666666666
# realiza la division de  4 / 20 = 0.2
# realiza la division de 9 / 3 = 3.0
# realiza la division de  7 / 21 = 0.3333333333333333
# realiza la division de 7 / 17 = 0.4117647058823529
# realiza la divison de 5 / 10 = 0.5
# realiza la division de 3 / 6 = 0.5
# realiza la division de  6 / 12 = 0.5
# realiza la division de 9 / 2 = 4.5

# %%
print("realiza la suma de 77 + 15 =" , 77 + 15 )
print("realiza la suma de  12 + 9 =" , 12 + 9 )
print("realiza la suma de 6 + 8 0" , 6 + 8 )
print("realiza la suma de 4 + 33 =" , 4 + 16 )
print("realiza la suma de 17 + 8 =" , 17 + 8 )
print("realiza la suma de 3 + 4 =" , 3 + 4 )
print("realiza la suma de 1 + 8 =" , 1 + 8 )
print("realiza la suma de 3 + 81 =" , 3 + 81 )
print("realiza la suma de 4 + 61 =" , 4 + 31 )
print("realiza la suma de 6 + 74 =" , 6 + 74 )
# Out:
# realiza la suma de 77 + 15 = 92
# realiza la suma de  12 + 9 = 21
# realiza la suma de 6 + 8 0 14
# realiza la suma de 4 + 33 = 20
# realiza la suma de 17 + 8 = 25
# realiza la suma de 3 + 4 = 7
# realiza la suma de 1 + 8 = 9
# realiza la suma de 3 + 81 = 84
# realiza la suma de 4 + 61 = 35
# realiza la suma de 6 + 74 = 80
